# %%
import pandas as pd

# %%
df = pd.read_json("d1.json")
df
# Out:
#                         sent_id  \
# 0     20020304/20.42.01-25605-0
# 1     20020304/20.42.01-25605-1
# 2     20020304/20.42.01-25605-2
# 3     20020304/20.42.01-25605-3
# 4     20020304/20.42.01-25605-4
# ...                         ...
# 2058   20010705/01.24.22-5235-6
# 2059   20010705/01.24.22-5235-7
# 2060   20010705/01.24.22-5235-8
# 2061   20010705/01.24.22-5235-9
# 2062  20010705/01.24.22-5235-10
#
#                                                    text  \
# 0     [ " Opinion " : " Independence of UNCHR impugn...
# 1     The United Nations human rights rapporteur , M...
# 2     Copithorne , who has served in the UN post sin...
# 3     The UN rapporteur 's new report on Iran , whic...
# 4     In most cases he described the legal punishmen...
# ...                                                 ...
# 2058  The owner put down the animal , although the v...
# 2059  The latter took the cow 's head to a lab , whe...
# 2060  The owner and a neighbor who had helped him pu...
# ...

# %%
df[df['opinions'] == '[]']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# ...
